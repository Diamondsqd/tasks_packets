# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('demodata.csv')

# %%
df
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 6         6  2008-05-06      Tue  0.007191  7.268427e+06   True
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
a = pd.Series([1, 2, 3, 4, 5], index = ['a', 'b', 'c', 'd', 'e'])

# %%
print(a['e'])
# Out:
# 5

# %%
labels = ['a', 'b', 'c']
my_list = [10, 20, 30]
arr = np.array([10, 20, 30])
d = {'a':10, 'b':20, 'c':30}

# %%
s = pd.Series(data = my_list)

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s = pd.Series(data = my_list, index = labels)

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series(data = [2, 3, 1, 4], index = ['USA', 'Germany', 'Russia', 'Japan'])

# %%
ser2 = pd.Series(data = [1, 2, 5, 4], index = ['USA', 'Germany', 'Italy', 'Japan'])

# %%
ser1 + ser2
# Out:
# Germany    5.0
# Italy      NaN
# Japan      8.0
# Russia     NaN
# USA        3.0
# dtype: float64

# %%
df1 = pd.DataFrame(
    data = [[5, True, 'x', 2.7],
            [8, True, 'y', 3.1],
            [13, False, 'z', np.NaN]],
    index = ['A', 'B', 'C'],
    columns = ['num', 'bool', 'str', 'real']
)

# %%
df1
# Out:
#    num   bool str  real
# A    5   True   x   2.7
# B    8   True   y   3.1
# C   13  False   z   NaN

# %%
df1.to_csv('testdf.csv', sep = ',')

# %%
df
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 6         6  2008-05-06      Tue  0.007191  7.268427e+06   True
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
df.shape
# Out:
# (10, 6)

# %%
df.head(3)
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False

# %%
df.tail(3)
# Out:
#    clientid        date weekdays     gains        prices     up
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   clientid  10 non-null     int64
#  1   date      10 non-null     object
#  2   weekdays  10 non-null     object
#  3   gains     10 non-null     float64
#  4   prices    10 non-null     float64
#  5   up        10 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(2)
# memory usage: 394.0+ bytes

# %%
df.describe()
# Out:
#        clientid      gains        prices
# count  10.00000  10.000000  1.000000e+01
# mean    4.50000  -0.425495  5.654715e+06
# std     3.02765   0.690446  3.485657e+06
# min     0.00000  -1.580369  9.371634e+05
# 25%     2.25000  -0.821761  2.232515e+06
# 50%     4.50000  -0.475796  7.392721e+06
# 75%     6.75000   0.058941  8.290031e+06
# max     9.00000   0.674497  9.589767e+06

# %%
df[df.weekdays == 'Wed']
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True

# %%
df1 = pd.read_csv('titanic.csv')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
df1['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df1['relatives'] = df1['SibSp'] + df1['Parch']

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1[df1.Age < 2][df1.Survived == 1]
# Out:
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 172          173         1       3     Johnson, Miss. Eleanor Ileen  female
# 183          184         1       2        Becker, Master. Richard F    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 788          789         1       3       Dean, Master. Bertram Vere    male
# ...

# %%
male_surv = df1[df1.Sex == 'male'][df1.Survived == 1].shape[0]
male_surv
# Out:
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 109

# %%
female_surv = df1[df1.Sex == 'female'][df1.Survived == 1].shape[0]
female_surv
# Out:
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 233

# %%
surv = df1[df1.Survived == 1].shape[0]
surv
# Out:
# 342

# %%
dead = df1[df1.Survived == 0].shape[0]
dead
# Out:
# 549

# %%
classes = df1['Pclass'].unique()

# %%
classes
# Out:
# array([3, 1, 2], dtype=int64)

# %%
for i in classes:
    print(f'В {i} классе было {df1[df1.Pclass == i].shape[0]} пассажиров')
# Out:
# В 3 классе было 491 пассажиров
# В 1 классе было 216 пассажиров
# В 2 классе было 184 пассажиров

# %%
df1['Pclass'] = df1['Pclass'].replace(1, 'Элита')

# %%
df1['Pclass'] = df1['Pclass'].replace(2, 'Средний класс')

# %%
df1['Pclass'] = df1['Pclass'].replace(3, 'Работяги')

# %%
df1
# Out:
#      PassengerId  Survived         Pclass  \
# 0              1         0       Работяги
# 1              2         1          Элита
# 2              3         1       Работяги
# 3              4         1          Элита
# 4              5         0       Работяги
# ..           ...       ...            ...
# 886          887         0  Средний класс
# 887          888         1          Элита
# 888          889         0       Работяги
# 889          890         1          Элита
# 890          891         0       Работяги
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
classes = df1['Pclass'].unique()

# %%
classes
# Out:
# array(['Работяги', 'Элита', 'Средний класс'], dtype=object)

# %%
for i in classes:
    print(f'В классе {i} было {df1[df1.Pclass == i].shape[0]} пассажиров')
# Out:
# В классе Работяги было 491 пассажиров
# В классе Элита было 216 пассажиров
# В классе Средний класс было 184 пассажиров

# %%
vals = [surv, dead]
labels = ['survived', 'dead']
fig, diag = plt.subplots()
diag.pie(vals, labels = labels, autopct = '%1.1f%%')
diag.axis('equal')
diag.set_title('Соотношение выживших и умерших')
plt.show()

# %%
vals = [male_surv, female_surv]
labels = ['Мужчины', 'Женщины']
fig, diag = plt.subplots()
diag.pie(vals, labels = labels, autopct = '%1.1f%%')
diag.axis('equal')
diag.set_title('Соотношение выживших мужчин и женщин')
plt.show()

# %%
vals = []
labels = []
for i in classes:
    vals.append(df1[df1.Pclass == i].shape[0])
    labels.append(i)
fig, diag = plt.subplots()
diag.pie(vals, labels = labels, autopct = '%1.1f%%')
diag.axis('equal')
diag.set_title('Соотношение количества людей в разных классах')
plt.show()

# %%
df1['Fare_bin'] = df1['Fare'] < 20

# %%
df1
# Out:
#      PassengerId  Survived         Pclass  \
# 0              1         0       Работяги
# 1              2         1          Элита
# 2              3         1       Работяги
# 3              4         1          Элита
# 4              5         0       Работяги
# ..           ...       ...            ...
# 886          887         0  Средний класс
# 887          888         1          Элита
# 888          889         0       Работяги
# 889          890         1          Элита
# 890          891         0       Работяги
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df1['Fare_bin'] = df1['Fare_bin'].replace([True, False], ['Дешевый билет', 'Дорогой билет'])

# %%
df1
# Out:
#      PassengerId  Survived         Pclass  \
# 0              1         0       Работяги
# 1              2         1          Элита
# 2              3         1       Работяги
# 3              4         1          Элита
# 4              5         0       Работяги
# ..           ...       ...            ...
# 886          887         0  Средний класс
# 887          888         1          Элита
# 888          889         0       Работяги
# 889          890         1          Элита
# 890          891         0       Работяги
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
vals = [df1[df1.Fare < 20].shape[0], df1[df1.Fare >= 20].shape[0]]
labels = ['Дешевые', 'Дорогие']
fig, diag = plt.subplots()
diag.pie(vals, labels = labels, autopct = '%1.1f%%')
diag.axis('equal')
diag.set_title('Соотношение дорогих и дешевых билетов')
plt.show()

# %%
average_age_surv = df1[df1.Survived == 1]['Age'].mean()

# %%
average_age_surv
# Out:
# 28.343689655172415

# %%
average_age_dead = df1[df1.Survived == 0]['Age'].mean()

# %%
average_age_dead
# Out:
# 30.62617924528302

# %%
df2 = df1.fillna(0)
df2[df2.Age == 0].shape[0]
df2
# Out:
#      PassengerId  Survived         Pclass  \
# 0              1         0       Работяги
# 1              2         1          Элита
# 2              3         1       Работяги
# 3              4         1          Элита
# 4              5         0       Работяги
# ..           ...       ...            ...
# 886          887         0  Средний класс
# 887          888         1          Элита
# 888          889         0       Работяги
# 889          890         1          Элита
# 890          891         0       Работяги
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
plt.hist(df1[df1.Survived == 1][df1.Age > 0]['Age'], bins = 80 // 5, color = 'green')
plt.hist(df1[df1.Survived == 0][df1.Age > 0]['Age'], bins = 80 // 5, alpha = 0.4, color = 'red')
plt.title('Распределение выживших(З)/мертвых(К) по возрастам')
plt.xlabel('Возраст')
plt.ylabel('Количество')
plt.show()
# Out:
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
vals = [df1[df1.Fare_bin == 'Дешевый билет'][df1.Survived == 1].shape[0], df1[df1.Fare_bin == 'Дешевый билет'][df1.Survived == 0].shape[0]]
labels = ['Выжили', 'Умерли']
fig, diag = plt.subplots()
diag.pie(vals, labels = labels, autopct = '%1.1f%%')
diag.axis('equal')
diag.set_title('Соотношение выживших и погибших с дешевыми билетами')
plt.show()
# Out:
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
vals = [df1[df1.Fare_bin == 'Дорогой билет'][df1.Survived == 1].shape[0], df1[df1.Fare_bin == 'Дорогой билет'][df1.Survived == 0].shape[0]]
labels = ['Выжили', 'Умерли']
fig, diag = plt.subplots()
diag.pie(vals, labels = labels, autopct = '%1.1f%%')
diag.axis('equal')
diag.set_title('Соотношение выживших и погибших с дорогими билетами')
plt.show()
# Out:
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# c:\program files (x86)\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
vals = df2[['Survived', 'Age']]
sns.boxplot(x = 'Survived', y = 'Age', data = vals)

# %%
sns.violinplot(x = 'Survived', y = 'Age', data = vals)
